# %% [markdown]
# ## What is fraud?
# According to Merriam-Webster dictionary, fraud is "intentional perversion of truth in order to induce another to part with something of value." In legal dictionary, fraud is "when a person deliberately practices deception in order to gain something unlawfully or unfairly." In most states, the act of fraud can be classified as either a civil or a criminal wrong.
#
# ## Types of fraud
#
# Fraud can be either hard fraud or soft fraud. <b>Hard fraud</b> occurs when someone deliberately plans a loss, such as an auto collision, auto theft, or house fire in order to claim payment for damages. Criminal rings are sometimes involved in hard fraud schemes. <b>Soft fraud</b> is far more common than hard fraud. Soft fraud is systematic abuse. For example, in an auto collision claim a claimant may claim more damage than actually occured. In a medical insurance claim an individual or an physician may exaggerate existing conditions that require overtreatment or result in the abuse of medical resources.
#
#
#
# |Fraud| Description|
# |:-- |:--|
# | Identity theft |   im payment for damages. Criminal rings are sometimes involved in hard fraud schemes. <b>Soft fraud</b> is far more common than hard fraud. Soft fraud is systematic abuse. For example, in an auto collision claim a claimant may claim more damage than actually occured. In a medical insurance claim an individual or an physician may exaggerate existing conditions that require overtreatment or result in the abuse of medical resources.
# |
# | Credit card fraud |
# | Auto insurance fraud | Staged auto accidents and false claims of injury false reports of stolen vehicles. False claims that an accident happened after a policy or coverage was purchased. False claims for damage that already existed claimants who concealed that a person excluded from coverage by their policy was driving at the time of the accident |
# | Health care provider fraud | Billing for services not rendered. Billing for a non-covered service as a covered service. Misrepresenting dates of service. Misrepresenting locations of service. Misrepresenting provider of service. Waiving of deductibles and/or co-payments.
# Incorrect reporting of diagnoses or procedures (includes unbundling). Overutilization of services. Corruption (kickbacks and bribery). False or unnecessary issuance of prescription drugs. |
#
#
#
# The Association of Certified Fraud Examiners (ACFE) developed the Occupational Fraud and Abuse Classification System, also known as the [Fraud Tree](http://www.acfe.com/uploadedFiles/ACFE_Website/Content/rttn/2016/fraud-tree.pdf). For a complete list of fraud types, including all hard frauds and soft frauds, see [A-Z of fraud](https://www.actionfraud.police.uk/a-z_of_fraud).
#
# ## Fraud trends in recent years
#
# ### In credit cards
# http://www.acfe.com/fraud-examiner.aspx?id=4294993042
#
#
# https://www.firstdata.com/downloads/pdf/STARFraudeBookFINAL.pdf
#
# https://www.signifyd.com/blog/2017/01/04/5-online-fraud-trends-watch-2017/
#
# ### In e-commerce
# https://risnews.com/fraud-trends-2017-what-watch-out-0
# https://www.radial.com/sites/default/files/Trends-in-Ecommerce-Digital-Fraud.pdf
#
#
# ### In healthcare
#
# ### In insurance claims
# https://s3.amazonaws.com/academia.edu.documents/33244024/insurancefraud.pdf?AWSAccessKeyId=AKIAIWOWYYGZ2Y53UL3A&Expires=1512857930&Signature=oobvqTnk5zu6AEF84lDNt4Q24WE%3D&response-content-disposition=inline%3B%20filename%3DINSURANCE_FRAUD.pdf
#
#
# ## Why does fraud occur?
#
# In order to deter fraud, it will be helpful to understand how and why people commit fraud.
# Knowing the “how” and "why" helps managers and business owners create policies and design internal controls to reduce the occurrence of fraud.
#
# <img src="images/fraud_triangle.jpg" align = "right" alt="Drawing" style="width: 200px;"/>
#
# There are three conditions that cause fraud to occus: <b>motivation</b>, <b>opportunity</b>, and <b>rationalization</b>. Suppose there is an altruistic physician with a patient who is unable to meet the payment for a required treatment. The "pressure" may be that the ultra-benevolent physian feels compassion to cover the bill. The "opportunity" can be that the physician covers the expense by submitting false claims. And the "rationalization" is the doctor feels justified by helping the patient. However, it is still a fraud. Likewise, suppose an employee is in charge of vendor selection. The "pressure" may be that the employee living beyond the means and facing a personal financial crisis. The "opportunity" is the employees having access to assets and information that allows them to both commit and conceal fraud. Th employee sets up a phantom vendor account and creates false invoices to collect payments to him. The employee may "rationalize" his action by thinking he would return the funds in a later time, or he has been conributing greatly to the company, etc.
#
# ## An effective anti-fraud strategy
#
# Many organisations are building formal systems and procedures in place to prevent, detect and respond to fraud. [Kroll](https://www.kroll.com/en-us/default.aspx) suveyed 1,265 executives worldwide and [reports](https://www.kroll.com/CMSPages/GetAzureFile.aspx?path=~%5Cmedia%5Cfiles%5Cintelligence-center%5Cglobal-fraud-report-2013-2014-english.pdf&hash=a84e800f9068acd3e3ce664e95666772c22ccf4547183e750ecf984b2041343d) that “All businesses are confronted with the risk of fraud. How they respond – the nature of their approach to prevention, detection, investigation and disclosure will separate those who manage through the issues from those who suffer significant loss.” An effective anti-fraud strategy has four main components:
#
# ### Prevention
# One way to deal with fraud is to adopt methods that
# will decrease motive, restrict opportunity and limit
# the ability for potential fraudsters to rationalise
# their actions. The aim of preventative controls is to
# reduce opportunity and remove temptation from
# potential offenders. Prevention techniques include
# the introduction of policies, procedures and controls
# as well as activities such as training and fraud
# awareness to stop fraud from occurring.
#
# https://risk.lexisnexis.com/insights-resources/article/preventing-healthcare-fraud-with-big-data-and-analytics
#
#
# ### Detection
# A fraud detection strategy should involve use of analytical and other procedures to highlight
# anomalies, and the introduction of reporting mechanisms that provide for communication
# of suspected fraudulent acts. Key elements of a comprehensive fraud detection system would
# include: Exception reporting, Data mining, Trend analysis, Ongoing risk assessment.
#
# ### Response
# The Plan defines authority levels, responsibilities for action, and reporting lines in the event of a
# suspected fraud or irregularity. It acts as a checklist of actions and a guide to follow in the event
# of fraud being suspected. The Plan is designed to enable Company to:
# (i) prevent further loss;
# (ii) establish and secure evidence necessary for criminal, civil and/or disciplinary action;
# (iii) determine when to contact the police and establish lines of communication;
# (iv) assign responsibility for investigating the incident;
# (v) minimize and recover losses;
# (vi) review the reasons for the incident, the measures taken to prevent a recurrence, and
# determine any action needed to strengthen future responses to fraud.
#
# ### Deterrance
# Deterrence involves eliminating factors that may cause fraud, whereas prevention involves identifying and stopping existing fraud.
#
# Fraud deterrence is based on the premise that fraud is not a random occurrence; fraud occurs where the conditions are right for it to occur. Fraud deterrence attacks the root causes and enablers of fraud; this analysis could reveal potential fraud opportunities in the process, but is performed on the premise that improving organizational procedures to reduce or eliminate the causal factors of fraud is the single best defense against fraud. Fraud deterrence involves both short term (procedural) and long term (cultural) initiatives.
#
# Fraud deterrence is not earlier fraud detection, and this is often a confusing point. Fraud detection involves a review of historical transactions to identify indicators of a non-conforming transaction. Deterrence involves an analysis of the conditions and procedures that affect fraud enablers, in essence, looking at what could happen in the future given the process definitions in place, and the people operating that process. Deterrence is a preventive measure – reducing input factors” (Cendrowski, Martin, Petro, The Handbook of Fraud Deterrence).
#
# ## Steps to create your fraud program
#
# <ol>
#   <li>Identify all the areas where fraud is expected to occur and the possible types of fraud.</li>
#   <li>Measure the risk of fraud and the overall exposure to the organization. Prioritize the risks based on fraud.</li>
#   <li>Apply machine learning in detecting frauds early.</li>
#   <li>Establish risk assessment and decide where to pay closer attention.</li>
#   <li>Monitor the activity with dashboard and data visualization. Communicate it throughout the organization so that employees in the organization are aware about the happening in the organization.</li>
#   <li>If there is any fraud found out, inform the management immediately to solve out the issue and to find out why it happened.</li>
#   <li>Fix the broken controls by enhancing the procedures and systems.</li>
# </ol>
#
#
#
#
# ## References
# Bolton, Richard J., and David J. Hand. “Statistical Fraud Detection: A Review.” Statistical Science, vol. 17, no. 3, 2002, pp. 235–249. JSTOR, JSTOR, www.jstor.org/stable/3182781.
#
# Sudjianto, A., Yuan, M., Kern, D., Nair, S., Zhang, A., & Cela-Díaz, F. (2010). Statistical Methods for Fighting Financial Crimes. Technometrics, 52(1), 5-19. Retrieved from http://www.jstor.org/stable/40586676
#
# Laurens, R., and CC Zou. "Using Credit/Debit Card Dynamic Soft Descriptor as Fraud Prevention System for Merchant." Global Communications Conference (GLOBECOM), 2016 IEEE, http://ieeexplore.ieee.org/abstract/document/7842369/
