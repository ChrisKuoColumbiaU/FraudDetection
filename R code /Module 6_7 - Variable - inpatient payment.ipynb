# %% [markdown]
# ### Healthcare - the cost of quality

# %%
#install.packages("zipcode")
library(dplyr)
#library(DataExplorer)
#library(xda)
library(ggplot2)
library(plotly)
library(data.table)
library(zipcode)
suppressPackageStartupMessages(library(tidyverse))
library(stringr)
#library(ggthemes)
suppressPackageStartupMessages(library(maps))
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Attaching package: ‘plotly’
#
# The following object is masked from ‘package:ggplot2’:
#
#     last_plot
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# The following object is masked from ‘package:graphics’:
#
#     layout
#
#
# Attaching package: ‘data.table’
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last

# %%
payment <- read.csv("/Users/chriskuo/Downloads/inpatientCharges.csv")

# %%
payment %>% arrange(Provider.Id, DRG.Definition) 
head(payment)
# Out:
#        DRG.Definition
# 1      039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 2      057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/O MCC
# 3      064 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION W MCC
# 4      065 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION W CC
# 5      066 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION W/O CC/MCC
# 6      069 - TRANSIENT ISCHEMIA
# 7      074 - CRANIAL & PERIPHERAL NERVE DISORDERS W/O MCC
# 8      101 - SEIZURES W/O MCC
# 9      176 - PULMONARY EMBOLISM W/O MCC
# 10     177 - RESPIRATORY INFECTIONS & INFLAMMATIONS W MCC
# 11     178 - RESPIRATORY INFECTIONS & INFLAMMATIONS W CC
# 12     189 - PULMONARY EDEMA & RESPIRATORY FAILURE
# 13     190 - CHRONIC OBSTRUCTIVE PULMONARY DISEASE W MCC
# 14     191 - CHRONIC OBSTRUCTIVE PULMONARY DISEASE W CC
# 15     192 - CHRONIC OBSTRUCTIVE PULMONARY DISEASE W/O CC/MCC
# 16     193 - SIMPLE PNEUMONIA & PLEURISY W MCC
# 17     194 - SIMPLE PNEUMONIA & PLEURISY W CC
# 18     195 - SIMPLE PNEUMONIA & PLEURISY W/O CC/MCC
# 19     202 - BRONCHITIS & ASTHMA W CC/MCC
# 20     207 - RESPIRATORY SYSTEM DIAGNOSIS W VENTILATOR SUPPORT 96+ HOURS
# 21     208 - RESPIRATORY SYSTEM DIAGNOSIS W VENTILATOR SUPPORT <96 HOURS
# 22     238 - MAJOR CARDIOVASC PROCEDURES W/O MCC
# 23     243 - PERMANENT CARDIAC PACEMAKER IMPLANT W CC
# 24     244 - PERMANENT CARDIAC PACEMAKER IMPLANT W/O CC/MCC
# 25     246 - PERC CARDIOVASC PROC W DRUG-ELUTING STENT W MCC OR 4+ VESSELS/STENTS
# 26     247 - PERC CARDIOVASC PROC W DRUG-ELUTING STENT W/O MCC
# 27     249 - PERC CARDIOVASC PROC W NON-DRUG-ELUTING STENT W/O MCC
# 28     251 - PERC CARDIOVASC PROC W/O CORONARY ARTERY STENT W/O MCC
# 29     252 - OTHER VASCULAR PROCEDURES W MCC
# 30     253 - OTHER VASCULAR PROCEDURES W CC
# ⋮      ⋮
# 163036 379 - G.I. HEMORRHAGE W/O CC/MCC
# 163037 392 - ESOPHAGITIS, GASTROENT & MISC DIGEST DISORDERS W/O MCC
# 163038 470 - MAJOR JOINT REPLACEMENT OR REATTACHMENT OF LOWER EXTREMITY W/O MCC
# 163039 473 - CERVICAL SPINAL FUSION W/O CC/MCC
# 163040 603 - CELLULITIS W/O MCC
# 163041 641 - MISC DISORDERS OF NUTRITION,METABOLISM,FLUIDS/ELECTROLYTES W/O MCC
# 163042 683 - RENAL FAILURE W CC
# 163043 690 - KIDNEY & URINARY TRACT INFECTIONS W/O MCC
# 163044 871 - SEPTICEMIA OR SEVERE SEPSIS W/O MV 96+ HOURS W MCC
# 163045 948 - SIGNS & SYMPTOMS W/O MCC
# 163046 470 - MAJOR JOINT REPLACEMENT OR REATTACHMENT OF LOWER EXTREMITY W/O MCC
# 163047 247 - PERC CARDIOVASC PROC W DRUG-ELUTING STENT W/O MCC
# 163048 287 - CIRCULATORY DISORDERS EXCEPT AMI, W CARD CATH W/O MCC
# 163049 292 - HEART FAILURE & SHOCK W CC
# 163050 293 - HEART FAILURE & SHOCK W/O CC/MCC
# 163051 310 - CARDIAC ARRHYTHMIA & CONDUCTION DISORDERS W/O CC/MCC
# 163052 313 - CHEST PAIN
# 163053 885 - PSYCHOSES
# 163054 460 - SPINAL FUSION EXCEPT CERVICAL W/O MCC
# 163055 470 - MAJOR JOINT REPLACEMENT OR REATTACHMENT OF LOWER EXTREMITY W/O MCC
# 163056 473 - CERVICAL SPINAL FUSION W/O CC/MCC
# 163057 491 - BACK & NECK PROC EXC SPINAL FUSION W/O CC/MCC
# 163058 194 - SIMPLE PNEUMONIA & PLEURISY W CC
# 163059 287 - CIRCULATORY DISORDERS EXCEPT AMI, W CARD CATH W/O MCC
# 163060 292 - HEART FAILURE & SHOCK W CC
# 163061 293 - HEART FAILURE & SHOCK W/O CC/MCC
# 163062 603 - CELLULITIS W/O MCC
# 163063 690 - KIDNEY & URINARY TRACT INFECTIONS W/O MCC
# 163064 470 - MAJOR JOINT REPLACEMENT OR REATTACHMENT OF LOWER EXTREMITY W/O MCC
# 163065 690 - KIDNEY & URINARY TRACT INFECTIONS W/O MCC
#        Provider.Id Provider.Name
# 1      10001       SOUTHEAST ALABAMA MEDICAL CENTER
# 2      10001       SOUTHEAST ALABAMA MEDICAL CENTER
# 3      10001       SOUTHEAST ALABAMA MEDICAL CENTER
# 4      10001       SOUTHEAST ALABAMA MEDICAL CENTER
# 5      10001       SOUTHEAST ALABAMA MEDICAL CENTER
# 6      10001       SOUTHEAST ALABAMA MEDICAL CENTER
# 7      10001       SOUTHEAST ALABAMA MEDICAL CENTER
# 8      10001       SOUTHEAST ALABAMA MEDICAL CENTER
# 9      10001       SOUTHEAST ALABAMA MEDICAL CENTER
# 10     10001       SOUTHEAST ALABAMA MEDICAL CENTER
# 11     10001       SOUTHEAST ALABAMA MEDICAL CENTER
# 12     10001       SOUTHEAST ALABAMA MEDICAL CENTER
# 13     10001       SOUTHEAST ALABAMA MEDICAL CENTER
# 14     10001       SOUTHEAST ALABAMA MEDICAL CENTER
# 15     10001       SOUTHEAST ALABAMA MEDICAL CENTER
# 16     10001       SOUTHEAST ALABAMA MEDICAL CENTER
# 17     10001       SOUTHEAST ALABAMA MEDICAL CENTER
# 18     10001       SOUTHEAST ALABAMA MEDICAL CENTER
# 19     10001       SOUTHEAST ALABAMA MEDICAL CENTER
# 20     10001       SOUTHEAST ALABAMA MEDICAL CENTER
# 21     10001       SOUTHEAST ALABAMA MEDICAL CENTER
# 22     10001       SOUTHEAST ALABAMA MEDICAL CENTER
# 23     10001       SOUTHEAST ALABAMA MEDICAL CENTER
# 24     10001       SOUTHEAST ALABAMA MEDICAL CENTER
# 25     10001       SOUTHEAST ALABAMA MEDICAL CENTER
# 26     10001       SOUTHEAST ALABAMA MEDICAL CENTER
# 27     10001       SOUTHEAST ALABAMA MEDICAL CENTER
# 28     10001       SOUTHEAST ALABAMA MEDICAL CENTER
# 29     10001       SOUTHEAST ALABAMA MEDICAL CENTER
# 30     10001       SOUTHEAST ALABAMA MEDICAL CENTER
# ⋮      ⋮           ⋮
# 163036 670068      TEXAS HEALTH PRESBYTERIAN HOSPITAL FLOWER MOUND
# 163037 670068      TEXAS HEALTH PRESBYTERIAN HOSPITAL FLOWER MOUND
# 163038 670068      TEXAS HEALTH PRESBYTERIAN HOSPITAL FLOWER MOUND
# 163039 670068      TEXAS HEALTH PRESBYTERIAN HOSPITAL FLOWER MOUND
# 163040 670068      TEXAS HEALTH PRESBYTERIAN HOSPITAL FLOWER MOUND
# 163041 670068      TEXAS HEALTH PRESBYTERIAN HOSPITAL FLOWER MOUND
# 163042 670068      TEXAS HEALTH PRESBYTERIAN HOSPITAL FLOWER MOUND
# 163043 670068      TEXAS HEALTH PRESBYTERIAN HOSPITAL FLOWER MOUND
# 163044 670068      TEXAS HEALTH PRESBYTERIAN HOSPITAL FLOWER MOUND
# 163045 670068      TEXAS HEALTH PRESBYTERIAN HOSPITAL FLOWER MOUND
# 163046 670069      METHODIST MCKINNEY HOSPITAL
# 163047 670071      TEXAS HEALTH HEART & VASCULAR HOSPITAL ARLINGTON
# 163048 670071      TEXAS HEALTH HEART & VASCULAR HOSPITAL ARLINGTON
# 163049 670071      TEXAS HEALTH HEART & VASCULAR HOSPITAL ARLINGTON
# 163050 670071      TEXAS HEALTH HEART & VASCULAR HOSPITAL ARLINGTON
# 163051 670071      TEXAS HEALTH HEART & VASCULAR HOSPITAL ARLINGTON
# 163052 670071      TEXAS HEALTH HEART & VASCULAR HOSPITAL ARLINGTON
# 163053 670072      WESTBURY COMMUNITY HOSPITAL, LLC
# 163054 670073      METHODIST HOSPITAL FOR SURGERY
# 163055 670073      METHODIST HOSPITAL FOR SURGERY
# 163056 670073      METHODIST HOSPITAL FOR SURGERY
# 163057 670073      METHODIST HOSPITAL FOR SURGERY
# 163058 670075      ST LUKE'S HOSPITAL AT THE VINTAGE, LLC
# 163059 670075      ST LUKE'S HOSPITAL AT THE VINTAGE, LLC
# 163060 670075      ST LUKE'S HOSPITAL AT THE VINTAGE, LLC
# 163061 670075      ST LUKE'S HOSPITAL AT THE VINTAGE, LLC
# 163062 670075      ST LUKE'S HOSPITAL AT THE VINTAGE, LLC
# 163063 670075      ST LUKE'S HOSPITAL AT THE VINTAGE, LLC
# 163064 670076      HERITAGE PARK SURGICAL HOSPITAL
# 163065 670077      METHODIST WEST HOUSTON HOSPITAL
#        Provider.Street.Address    Provider.City Provider.State
# 1      1108 ROSS CLARK CIRCLE     DOTHAN        AL
# 2      1108 ROSS CLARK CIRCLE     DOTHAN        AL
# 3      1108 ROSS CLARK CIRCLE     DOTHAN        AL
# 4      1108 ROSS CLARK CIRCLE     DOTHAN        AL
# 5      1108 ROSS CLARK CIRCLE     DOTHAN        AL
# 6      1108 ROSS CLARK CIRCLE     DOTHAN        AL
# 7      1108 ROSS CLARK CIRCLE     DOTHAN        AL
# 8      1108 ROSS CLARK CIRCLE     DOTHAN        AL
# 9      1108 ROSS CLARK CIRCLE     DOTHAN        AL
# 10     1108 ROSS CLARK CIRCLE     DOTHAN        AL
# 11     1108 ROSS CLARK CIRCLE     DOTHAN        AL
# 12     1108 ROSS CLARK CIRCLE     DOTHAN        AL
# 13     1108 ROSS CLARK CIRCLE     DOTHAN        AL
# 14     1108 ROSS CLARK CIRCLE     DOTHAN        AL
# 15     1108 ROSS CLARK CIRCLE     DOTHAN        AL
# 16     1108 ROSS CLARK CIRCLE     DOTHAN        AL
# 17     1108 ROSS CLARK CIRCLE     DOTHAN        AL
# 18     1108 ROSS CLARK CIRCLE     DOTHAN        AL
# 19     1108 ROSS CLARK CIRCLE     DOTHAN        AL
# 20     1108 ROSS CLARK CIRCLE     DOTHAN        AL
# 21     1108 ROSS CLARK CIRCLE     DOTHAN        AL
# 22     1108 ROSS CLARK CIRCLE     DOTHAN        AL
# 23     1108 ROSS CLARK CIRCLE     DOTHAN        AL
# 24     1108 ROSS CLARK CIRCLE     DOTHAN        AL
# 25     1108 ROSS CLARK CIRCLE     DOTHAN        AL
# 26     1108 ROSS CLARK CIRCLE     DOTHAN        AL
# 27     1108 ROSS CLARK CIRCLE     DOTHAN        AL
# 28     1108 ROSS CLARK CIRCLE     DOTHAN        AL
# 29     1108 ROSS CLARK CIRCLE     DOTHAN        AL
# 30     1108 ROSS CLARK CIRCLE     DOTHAN        AL
# ⋮      ⋮                          ⋮             ⋮
# 163036 4400 LONG PRAIRIE ROAD     FLOWER MOUND  TX
# 163037 4400 LONG PRAIRIE ROAD     FLOWER MOUND  TX
# 163038 4400 LONG PRAIRIE ROAD     FLOWER MOUND  TX
# 163039 4400 LONG PRAIRIE ROAD     FLOWER MOUND  TX
# 163040 4400 LONG PRAIRIE ROAD     FLOWER MOUND  TX
# 163041 4400 LONG PRAIRIE ROAD     FLOWER MOUND  TX
# 163042 4400 LONG PRAIRIE ROAD     FLOWER MOUND  TX
# 163043 4400 LONG PRAIRIE ROAD     FLOWER MOUND  TX
# 163044 4400 LONG PRAIRIE ROAD     FLOWER MOUND  TX
# 163045 4400 LONG PRAIRIE ROAD     FLOWER MOUND  TX
# 163046 8000 W ELDORADO PKWY       MC KINNEY     TX
# 163047 811 WRIGHT STREET          ARLINGTON     TX
# 163048 811 WRIGHT STREET          ARLINGTON     TX
# 163049 811 WRIGHT STREET          ARLINGTON     TX
# 163050 811 WRIGHT STREET          ARLINGTON     TX
# 163051 811 WRIGHT STREET          ARLINGTON     TX
# 163052 811 WRIGHT STREET          ARLINGTON     TX
# 163053 5556 GASMER                HOUSTON       TX
# 163054 17101 DALLAS PARKWAY       ADDISON       TX
# 163055 17101 DALLAS PARKWAY       ADDISON       TX
# 163056 17101 DALLAS PARKWAY       ADDISON       TX
# 163057 17101 DALLAS PARKWAY       ADDISON       TX
# 163058 20171 CHASEWOOD PARK DRIVE HOUSTON       TX
# 163059 20171 CHASEWOOD PARK DRIVE HOUSTON       TX
# 163060 20171 CHASEWOOD PARK DRIVE HOUSTON       TX
# 163061 20171 CHASEWOOD PARK DRIVE HOUSTON       TX
# 163062 20171 CHASEWOOD PARK DRIVE HOUSTON       TX
# 163063 20171 CHASEWOOD PARK DRIVE HOUSTON       TX
# 163064 3601 CALAIS DRIVE          SHERMAN       TX
# 163065 18500 KATY FREEWAY         HOUSTON       TX
#        Provider.Zip.Code Hospital.Referral.Region.Description Total.Discharges
# 1      36301             AL - Dothan                           91
# 2      36301             AL - Dothan                           38
# 3      36301             AL - Dothan                           84
# 4      36301             AL - Dothan                          169
# 5      36301             AL - Dothan                           33
# 6      36301             AL - Dothan                           37
# 7      36301             AL - Dothan                           13
# 8      36301             AL - Dothan                           27
# 9      36301             AL - Dothan                           33
# 10     36301             AL - Dothan                           21
# 11     36301             AL - Dothan                           22
# 12     36301             AL - Dothan                          112
# 13     36301             AL - Dothan                           73
# 14     36301             AL - Dothan                          164
# 15     36301             AL - Dothan                           49
# 16     36301             AL - Dothan                           55
# 17     36301             AL - Dothan                          107
# 18     36301             AL - Dothan                           20
# 19     36301             AL - Dothan                           29
# 20     36301             AL - Dothan                           19
# 21     36301             AL - Dothan                           86
# 22     36301             AL - Dothan                           62
# 23     36301             AL - Dothan                           44
# 24     36301             AL - Dothan                           21
# 25     36301             AL - Dothan                           38
# 26     36301             AL - Dothan                          118
# 27     36301             AL - Dothan                           32
# 28     36301             AL - Dothan                           17
# 29     36301             AL - Dothan                           37
# 30     36301             AL - Dothan                           49
# ⋮      ⋮                 ⋮                                    ⋮
# 163036 75028             TX - Dallas                           12
# 163037 75028             TX - Dallas                           30
# 163038 75028             TX - Dallas                           46
# 163039 75028             TX - Dallas                           11
# 163040 75028             TX - Dallas                           21
# 163041 75028             TX - Dallas                           11
# 163042 75028             TX - Dallas                           11
# 163043 75028             TX - Dallas                           30
# 163044 75028             TX - Dallas                           14
# 163045 75028             TX - Dallas                           12
# 163046 75070             TX - Dallas                           55
# 163047 76012             TX - Fort Worth                       22
# 163048 76012             TX - Fort Worth                       22
# 163049 76012             TX - Fort Worth                       19
# 163050 76012             TX - Fort Worth                       12
# 163051 76012             TX - Fort Worth                       26
# 163052 76012             TX - Fort Worth                       14
# 163053 77035             TX - Houston                         553
# 163054 75001             TX - Dallas                           66
# 163055 75001             TX - Dallas                          111
# 163056 75001             TX - Dallas                           22
# 163057 75001             TX - Dallas                           20
# 163058 77070             TX - Houston                          16
# 163059 77070             TX - Houston                          11
# 163060 77070             TX - Houston                          12
# 163061 77070             TX - Houston                          11
# 163062 77070             TX - Houston                          13
# 163063 77070             TX - Houston                          18
# 163064 75090             TX - Dallas                           18
# 163065 77094             TX - Houston                          14
#        Average.Covered.Charges Average.Total.Payments Average.Medicare.Payments
# 1      $32963.07               $5777.24               $4763.73
# 2      $20312.78               $4894.76               $3865.50
# 3      $38820.39               $10260.21              $9167.08
# 4      $27345.10               $6542.08               $5438.50
# 5      $17605.51               $4596.39               $3618.93
# 6      $20688.83               $4134.10               $3103.40
# 7      $18489.15               $4876.00               $4097.23
# 8      $19619.70               $4667.22               $3249.66
# 9      $23680.30               $6020.27               $5338.09
# 10     $48240.09               $11634.52              $10553.23
# 11     $31341.59               $7873.54               $7017.50
# 12     $28807.61               $7254.19               $6552.40
# 13     $26582.76               $6738.57               $5957.19
# 14     $23894.34               $5464.65               $4578.85
# 15     $15609.81               $4482.18               $3003.53
# 16     $31350.52               $8148.67               $7403.25
# 17     $21096.94               $5832.73               $4615.95
# 18     $12034.15               $4021.00               $2953.60
# 19     $21906.24               $4825.41               $3728.24
# 20     $107347.52              $28246.68              $27831.31
# 21     $53051.04               $12710.83              $11963.56
# 22     $54708.17               $17711.45              $16083.06
# 23     $56938.70               $14922.15              $14005.43
# 24     $46950.14               $11537.66              $10575.00
# 25     $84912.15               $18301.07              $17307.68
# 26     $61844.96               $11087.40              $9816.35
# 27     $55815.12               $9887.68               $8300.56
# 28     $46396.17               $10194.00              $9402.47
# 29     $86504.43               $20657.29              $16209.35
# 30     $64586.71               $13576.61              $12723.79
# ⋮      ⋮                       ⋮                      ⋮
# 163036 $21443.50               $4747.00               $3900.66
# 163037 $17642.93               $4163.70               $3283.83
# 163038 $61863.69               $12321.86              $10429.26
# 163039 $57571.18               $12476.90              $9158.90
# 163040 $19142.04               $4903.52               $4086.04
# 163041 $20148.81               $4346.00               $3831.45
# 163042 $32246.45               $6420.00               $5808.36
# 163043 $20135.73               $5153.46               $4365.33
# 163044 $45911.50               $11338.71              $10671.57
# 163045 $15042.00               $3539.75               $2887.41
# 163046 $32115.50               $11180.81              $8709.45
# 163047 $61525.40               $10305.54              $8615.09
# 163048 $37101.86               $5767.04               $4995.27
# 163049 $25351.52               $5049.68               $4096.42
# 163050 $12827.00               $3404.00               $2649.33
# 163051 $9145.11                $3214.11               $1638.00
# 163052 $12660.35               $2731.00               $1679.85
# 163053 $9132.27                $4637.26               $3894.55
# 163054 $36652.98               $21244.78              $16357.18
# 163055 $28262.56               $11821.26              $8479.76
# 163056 $24905.90               $12529.22              $7848.54
# 163057 $14542.70               $5086.60               $4018.95
# 163058 $30699.81               $5211.00               $4574.25
# 163059 $53976.81               $6365.36               $5645.00
# 163060 $38656.91               $5288.00               $4839.91
# 163061 $24672.54               $6356.81               $2694.27
# 163062 $27816.30               $4300.00               $3690.46
# 163063 $27219.94               $4009.66               $3255.00
# 163064 $33310.61               $10063.77              $8491.44
# 163065 $22316.35               $4277.57               $2743.57
#   DRG.Definition                           Provider.Id
# 1 039 - EXTRACRANIAL PROCEDURES W/O CC/MCC 10001
# 2 039 - EXTRACRANIAL PROCEDURES W/O CC/MCC 10005
# 3 039 - EXTRACRANIAL PROCEDURES W/O CC/MCC 10006
# 4 039 - EXTRACRANIAL PROCEDURES W/O CC/MCC 10011
# 5 039 - EXTRACRANIAL PROCEDURES W/O CC/MCC 10016
# 6 039 - EXTRACRANIAL PROCEDURES W/O CC/MCC 10023
#   Provider.Name                    Provider.Street.Address    Provider.City
# 1 SOUTHEAST ALABAMA MEDICAL CENTER 1108 ROSS CLARK CIRCLE     DOTHAN
# 2 MARSHALL MEDICAL CENTER SOUTH    2505 U S HIGHWAY 431 NORTH BOAZ
# 3 ELIZA COFFEE MEMORIAL HOSPITAL   205 MARENGO STREET         FLORENCE
# 4 ST VINCENT'S EAST                50 MEDICAL PARK EAST DRIVE BIRMINGHAM
# 5 SHELBY BAPTIST MEDICAL CENTER    1000 FIRST STREET NORTH    ALABASTER
# 6 BAPTIST MEDICAL CENTER SOUTH     2105 EAST SOUTH BOULEVARD  MONTGOMERY
#   Provider.State Provider.Zip.Code Hospital.Referral.Region.Description
# 1 AL             36301             AL - Dothan
# 2 AL             35957             AL - Birmingham
# 3 AL             35631             AL - Birmingham
# 4 AL             35235             AL - Birmingham
# 5 AL             35007             AL - Birmingham
# 6 AL             36116             AL - Montgomery
#   Total.Discharges Average.Covered.Charges Average.Total.Payments
# 1 91               $32963.07               $5777.24
# 2 14               $15131.85               $5787.57
# 3 24               $37560.37               $5434.95
# 4 25               $13998.28               $5417.56
# 5 18               $31633.27               $5658.33
# 6 67               $16920.79               $6653.80
#   Average.Medicare.Payments
# 1 $4763.73
# 2 $4976.71
# 3 $4453.79
# 4 $4129.16
# 5 $4851.44
# 6 $5374.14

# %%
# Convert the average to numeric
p1 <- strsplit(x = as.character(payment$Average.Covered.Charges),split = "$",fixed = T)
payment$Average.Covered.Charges <- as.numeric(sapply(p1,"[[",2))
p1 <- strsplit(x = as.character(payment$Average.Total.Payments),split = "$",fixed = T)
payment$Average.Total.Payments <- as.numeric(sapply(p1,"[[",2))
p1 <- strsplit(x = as.character(payment$Average.Medicare.Payments),split = "$",fixed = T)
payment$Average.Medicare.Payments <- as.numeric(sapply(p1,"[[",2))
rm("p1")

# %%
#summary(payment)
colnames(payment)
# Out:
#  [1] "DRG.Definition"
#  [2] "Provider.Id"
#  [3] "Provider.Name"
#  [4] "Provider.Street.Address"
#  [5] "Provider.City"
#  [6] "Provider.State"
#  [7] "Provider.Zip.Code"
#  [8] "Hospital.Referral.Region.Description"
#  [9] "Total.Discharges"
# [10] "Average.Covered.Charges"
# [11] "Average.Total.Payments"
# [12] "Average.Medicare.Payments"

# %%
DRG_State_avg <- payment %>% group_by(DRG.Definition, Provider.State) %>%
       summarise( mean_total_discharges          = mean(Total.Discharges),
                  mean_average_covered_charges   = mean(Average.Covered.Charges),
                  mean_average_total_payments    = mean(Average.Total.Payments),
                  mean_average_medicare_payments = mean(Average.Medicare.Payments),                 
                  mean_count_trans =n()
                )
head(DRG_State_avg)
# Out:
#   DRG.Definition                           Provider.State mean_total_discharges
# 1 039 - EXTRACRANIAL PROCEDURES W/O CC/MCC AK             23.00000
# 2 039 - EXTRACRANIAL PROCEDURES W/O CC/MCC AL             38.21739
# 3 039 - EXTRACRANIAL PROCEDURES W/O CC/MCC AR             40.75000
# 4 039 - EXTRACRANIAL PROCEDURES W/O CC/MCC AZ             25.25000
# 5 039 - EXTRACRANIAL PROCEDURES W/O CC/MCC CA             25.59701
# 6 039 - EXTRACRANIAL PROCEDURES W/O CC/MCC CO             25.50000
#   mean_average_covered_charges mean_average_total_payments
# 1 34805.13                     8401.950
# 2 32044.44                     5743.612
# 3 27463.26                     6118.829
# 4 33443.36                     7271.556
# 5 56094.93                     8387.933
# 6 35252.21                     7051.922
#   mean_average_medicare_payments mean_count_trans
# 1 6413.780                        1
# 2 4599.593                       23
# 3 4938.712                       16
# 4 5912.833                       24
# 5 6878.955                       67
# 6 5419.930                       10

# %%
# Append the average statistics back to the data to derive the ratios.
per_provider <- payment %>% 
       left_join(DRG_State_avg, by=c("DRG.Definition","Provider.State")) %>%
       mutate( 
            ratio_total_discharges          = Total.Discharges/mean_total_discharges,
            ratio_average_covered_charges   = Average.Covered.Charges/mean_average_covered_charges,
            ratio_average_total_payments    = Average.Total.Payments/mean_average_total_payments,
            ratio_average_medicare_payments = Average.Medicare.Payments/mean_average_medicare_payments) %>%
       select(-mean_total_discharges,
              -mean_average_covered_charges,
              -mean_average_total_payments,
              -mean_average_medicare_payments,
              -mean_count_trans,
              -Total.Discharges,
              -Average.Covered.Charges,
              -Average.Total.Payments,
              -Average.Medicare.Payments
           ) %>% arrange(Provider.Id, DRG.Definition) 
#%>%
#           select(Provider.Id,DRG.Definition,Provider.Name,Provider.State,ratio_total_discharges,ratio_average_covered_charges,ratio_average_total_payments,ratio_average_medicare_payments)
    
head(per_provider)
# Out:
#   DRG.Definition                                                  Provider.Id
# 1 039 - EXTRACRANIAL PROCEDURES W/O CC/MCC                        10001
# 2 057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/O MCC             10001
# 3 064 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION W MCC      10001
# 4 065 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION W CC       10001
# 5 066 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION W/O CC/MCC 10001
# 6 069 - TRANSIENT ISCHEMIA                                        10001
#   Provider.Name                    Provider.Street.Address Provider.City
# 1 SOUTHEAST ALABAMA MEDICAL CENTER 1108 ROSS CLARK CIRCLE  DOTHAN
# 2 SOUTHEAST ALABAMA MEDICAL CENTER 1108 ROSS CLARK CIRCLE  DOTHAN
# 3 SOUTHEAST ALABAMA MEDICAL CENTER 1108 ROSS CLARK CIRCLE  DOTHAN
# 4 SOUTHEAST ALABAMA MEDICAL CENTER 1108 ROSS CLARK CIRCLE  DOTHAN
# 5 SOUTHEAST ALABAMA MEDICAL CENTER 1108 ROSS CLARK CIRCLE  DOTHAN
# 6 SOUTHEAST ALABAMA MEDICAL CENTER 1108 ROSS CLARK CIRCLE  DOTHAN
#   Provider.State Provider.Zip.Code Hospital.Referral.Region.Description
# 1 AL             36301             AL - Dothan
# 2 AL             36301             AL - Dothan
# 3 AL             36301             AL - Dothan
# 4 AL             36301             AL - Dothan
# 5 AL             36301             AL - Dothan
# 6 AL             36301             AL - Dothan
#   ratio_total_discharges ratio_average_covered_charges
# 1 2.381115               1.0286675
# 2 1.652174               0.8158866
# 3 2.313139               0.9223401
# 4 3.866473               1.1245200
# 5 1.117697               0.8331698
# 6 1.274946               1.1534556
#   ratio_average_total_payments ratio_average_medicare_payments
# 1 1.0058549                    1.0356851
# 2 0.9423239                    0.9029783
# 3 0.9459251                    0.9550971
# 4 0.9893687                    1.0014042
# 5 0.9967270                    1.0357761
# 6 0.9776143                    1.0023442

# %% [markdown]
# ### Hints:
#
# 1. You can modify the features. For example, you can use "median" instead of "mean" for the DRG/State averages.
#
# ### Next steps:
# You will prepare the modeling dataset for DBSCAN clustering. You are also encouraged to perform K-means to compare the results. The outliers will be identified by DBSCAN. Then you will use the principal component technique to reduce the features. The principal component is used only to visualize the results.
