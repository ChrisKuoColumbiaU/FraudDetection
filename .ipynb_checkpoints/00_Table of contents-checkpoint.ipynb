# %% [markdown]
# ## Table of Contents
#
# <ol>
#   <li>Introduction
#     <ul>
#       <li>Growing fraud risks</li>
#       <li>Mission: finding fraud fast</li>
#       <li>Machine learning for fraud detection</li>
#       <li>Why this book?</li>
#       <li>The features of this book</li>
#       <li>The structure of this book</li>
#     </ul>
#   </li>
#   <li>Best practices for fraud risk management
#     <ul>
#       <li></li>
#       <li></li>
#       <li></li>
#     </ul>
#   </li>
#   <li>Feature engineering for fraud detection
#     <ul>
#       <li>Features for credit card transaction fraud</li>
#       <li>Features for healthcare fraud, waste and abuse
#         <ul>
#           <li>The nature of the problem: medical fraud and abuse</li>
#           <li>Types of medical fraud and abuse</li>
#           <li>Feature engineering on medical fraud and abuse: one real example</li>
#           <li>Understand ICD10, CPT and E/M codes to create features</li>
#         </ul>
#     </ul>
#   </li>
#   <li>Extracting features from texts
#     <ul>
#       <li></li>
#       <li></li>
#       <li></li>
#     </ul>
#   </li>
#   <li>Sampling techniques for extremely imbalanced data
#     <ul>
#       <li>What is imbalanced data?</li>
#       <li>Why an ROC curve cannot measure well</li>
#       <li>Undersampling techniques
#         <ul>
#           <li>Random undersampling for the majority class</li>
#           <li>NearMiss</li>
#           <li>Condensed Nearest Neighbor Rule (CNN)</li>
#           <li>TomekLinks</li>
#           <li>Edited Nearest Neighbor Rule (ENN)</li>
#           <li>NeighbourhoodCleaningRule</li>
#           <li>ClusterCentroids</li>
#           <li>NeighbourhoodCleaningRule</li>
#         </ul>
#       <li>Oversampling techniques
#         <ul>
#           <li>Random oversampling for the minority class</li>
#           <li>Synthetic Minority Oversampling Technique (SMOTE)</li>
#           <li>ADASYN: Adaptive Synthetic Sampling</li>
#         </ul>
#     </ul>
#   </li>
#   <li>Supervised learning techniques for fraud detection
#     <ul>
#       <li>Under-sample the dataset</li>
#       <li>GBM</li>
#       <li>Xgboost</li>
#       <li>What is deep learning?</li>
#       <li>Deep learning using Keras</li>
#       <li>Keras for credit card fraud detection</li>
#     </ul>
#   </li>
#   <li>Supervised learning techniques more considerations
#     <ul>
#       <li>Milk</li>
#       <li>Bread</li>
#       <li>Cheese</li>
#     </ul>
#   </li>
#   <li>Unsupervised learning techniques for fraud detection
#     <ul>
#       <li>Z-score</li>
#       <li>Median absolute deviation (MAD)</li>
#       <li>One-class Support Vector Machine (One-class SVM)</li>
#       <li>Hidden markov model (HMM)</li>
#       <li>Gaussian Mixture Model (GMM)</li>
#       <li>Density-based spatial clustering of applications with noise (DBSCAN)</li>
#       <li>MeanShift</li>
#       <li>Hierarchical clustering</li>
#       <li>Self-organizing maps (SOM)</li>
#     </ul>
#   </li>
#
#
#
#   <li>Graph-based techniques for fraud detection
#     <ul>
#       <li>Fraud ring example 1: Auto accident insurance claims</li>
#       <li>Fraud ring example 2: First-party fraud in retail banking</li>
#       <li>Why the "traditional" anomaly dection techniques cannot catch them?</li>
#       <li>Graph database: Neo4j</li>
#       <li>Using Neo4j to identify fraud ring</li>
#     </ul>
#   </li>
#   <li>Semi-supervised techniques for fraud detection
#     <ul>
#       <li></li>
#       <li></li>
#       <li></li>
#     </ul>
#   </li>
# </ol>
